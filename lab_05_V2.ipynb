# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
from keras.datasets import cifar10
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import cv2

font = {'weight' : 'bold',
        'size'   : 12}

matplotlib.rc('font', **font)

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

labels = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}

def display_random_images(x_data: np.array, y_data: np.array, count: int = 10) -> None:
  index = np.arange(len(x_data))
  selected_ind = np.random.choice(index, count)

  selected_img = x_data[selected_ind]
  selected_labels_encoded = y_data[selected_ind]
  selected_labels = [labels[x[0]] for x in selected_labels_encoded]

  concat_img = np.concatenate(selected_img, axis=1)

  plt.figure(figsize=(20,10))
  plt.imshow(concat_img)

  for id_label, label in enumerate(selected_labels):
    plt.text((32/2) + 32*id_label - len(label), 32*(5/4), label)
  plt.axis('off')
  plt.show()

display_random_images(X_train, y_train)

def display_channels_separately(image: np.array) -> None:

  plt.figure()
  fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(10, 5))

  axs[0].imshow(image[:,:,0],cmap='Reds')
  axs[1].imshow(image[:,:,1],cmap='Blues')
  axs[2].imshow(image[:,:,2],cmap='Greens')
  axs[3].imshow(image)

  plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
display_channels_separately(X_train[50])


X_train_scaled = X_train.astype('float32') / 255.0
X_test_scaled = X_test.astype('float32') / 255.0


y_train_encoded = to_categorical(y_train, num_classes=10)
y_test_encoded = to_categorical(y_test, num_classes=10)

model = Sequential()

model.add(Flatten(input_shape=(32, 32, 3)))

model.add(Dense(1024, activation='gelu', kernel_regularizer=l2(0.0005)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Dense(512, activation='gelu', kernel_regularizer=l2(0.0005)))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(256, activation='gelu', kernel_regularizer=l2(0.0005)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(10, activation='softmax'))

model.summary()

optimizer = Adam(learning_rate=0.001)

model.compile(
    loss='categorical_crossentropy',
    optimizer=optimizer,
    metrics=['accuracy']
)


callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True),
    ReduceLROnPlateau(factor=0.3, patience=5)
]
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │     3,146,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,812,618 (14.54 MB)
#  Trainable params: 3,809,034 (14.53 MB)
#  Non-trainable params: 3,584 (14.00 KB)

# %%
# TRAINING
history = model.fit(
    X_train_scaled,
    y_train_encoded,
    epochs=100,
    batch_size=128,
    validation_split=0.2,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 45s 130ms/step - accuracy: 0.3291 - loss: 3.1416 - val_accuracy: 0.3301 - val_loss: 2.8629 - learning_rate: 0.0010
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 46s 146ms/step - accuracy: 0.3905 - loss: 2.5309 - val_accuracy: 0.2970 - val_loss: 2.5903 - learning_rate: 0.0010
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 137ms/step - accuracy: 0.4076 - loss: 2.2335 - val_accuracy: 0.3329 - val_loss: 2.3188 - learning_rate: 0.0010
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 130ms/step - accuracy: 0.4261 - loss: 2.0624 - val_accuracy: 0.2724 - val_loss: 2.5555 - learning_rate: 0.0010
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.4182 - loss: 2.0031 - val_accuracy: 0.2527 - val_loss: 2.4237 - learning_rate: 0.0010
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.4257 - loss: 1.9507 - val_accuracy: 0.3021 - val_loss: 2.2711 - learning_rate: 0.0010
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 130ms/step - accuracy: 0.4252 - loss: 1.9215 - val_accuracy: 0.2365 - val_loss: 2.4669 - learning_rate: 0.0010
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.4286 - loss: 1.9004 - val_accuracy: 0.2368 - val_loss: 2.4716 - learning_rate: 0.0010
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 129ms/step - accuracy: 0.4328 - loss: 1.8770 - val_accuracy: 0.2943 - val_loss: 2.3382 - learning_rate: 0.0010
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.4341 - loss: 1.8735 - val_accuracy: 0.3310 - val_loss: 2.1756 - learning_rate: 0.0010
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.4331 - loss: 1.8714 - val_accuracy: 0.1995 - val_loss: 2.6830 - learning_rate: 0.0010
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 127ms/step - accuracy: 0.4304 - loss: 1.8804 - val_accuracy: 0.1955 - val_loss: 2.7298 - learning_rate: 0.0010
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 129ms/step - accuracy: 0.4381 - loss: 1.8707 - val_accuracy: 0.2705 - val_loss: 2.2884 - learning_rate: 0.0010
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 128ms/step - accuracy: 0.4367 - loss: 1.8727 - val_accuracy: 0.2807 - val_loss: 2.2678 - learning_rate: 0.0010
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 127ms/step - accuracy: 0.4390 - loss: 1.8670 - val_accuracy: 0.3146 - val_loss: 2.1786 - learning_rate: 0.0010
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 128ms/step - accuracy: 0.4719 - loss: 1.7420 - val_accuracy: 0.4473 - val_loss: 1.7873 - learning_rate: 3.0000e-04
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 128ms/step - accuracy: 0.4825 - loss: 1.6705 - val_accuracy: 0.4163 - val_loss: 1.8279 - learning_rate: 3.0000e-04
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.4855 - loss: 1.6459 - val_accuracy: 0.4423 - val_loss: 1.7508 - learning_rate: 3.0000e-04
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.4848 - loss: 1.6270 - val_accuracy: 0.4571 - val_loss: 1.7059 - learning_rate: 3.0000e-04
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.4916 - loss: 1.6035 - val_accuracy: 0.4843 - val_loss: 1.6495 - learning_rate: 3.0000e-04
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 128ms/step - accuracy: 0.4945 - loss: 1.5892 - val_accuracy: 0.4385 - val_loss: 1.7451 - learning_rate: 3.0000e-04
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 129ms/step - accuracy: 0.4988 - loss: 1.5795 - val_accuracy: 0.4646 - val_loss: 1.6724 - learning_rate: 3.0000e-04
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 129ms/step - accuracy: 0.5013 - loss: 1.5701 - val_accuracy: 0.4489 - val_loss: 1.7157 - learning_rate: 3.0000e-04
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 138ms/step - accuracy: 0.5029 - loss: 1.5651 - val_accuracy: 0.4731 - val_loss: 1.6311 - learning_rate: 3.0000e-04
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 79s 129ms/step - accuracy: 0.5024 - loss: 1.5541 - val_accuracy: 0.4585 - val_loss: 1.6815 - learning_rate: 3.0000e-04
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 130ms/step - accuracy: 0.5069 - loss: 1.5444 - val_accuracy: 0.4501 - val_loss: 1.6962 - learning_rate: 3.0000e-04
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.5101 - loss: 1.5367 - val_accuracy: 0.4730 - val_loss: 1.6459 - learning_rate: 3.0000e-04
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.5136 - loss: 1.5264 - val_accuracy: 0.4885 - val_loss: 1.6160 - learning_rate: 3.0000e-04
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 132ms/step - accuracy: 0.5156 - loss: 1.5262 - val_accuracy: 0.4729 - val_loss: 1.6437 - learning_rate: 3.0000e-04
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 81s 128ms/step - accuracy: 0.5159 - loss: 1.5233 - val_accuracy: 0.4828 - val_loss: 1.6245 - learning_rate: 3.0000e-04
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 127ms/step - accuracy: 0.5176 - loss: 1.5155 - val_accuracy: 0.4818 - val_loss: 1.6202 - learning_rate: 3.0000e-04
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.5202 - loss: 1.5165 - val_accuracy: 0.4059 - val_loss: 1.8432 - learning_rate: 3.0000e-04
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 127ms/step - accuracy: 0.5200 - loss: 1.5089 - val_accuracy: 0.4970 - val_loss: 1.5907 - learning_rate: 3.0000e-04
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.5242 - loss: 1.5021 - val_accuracy: 0.4818 - val_loss: 1.6190 - learning_rate: 3.0000e-04
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 127ms/step - accuracy: 0.5259 - loss: 1.4972 - val_accuracy: 0.4602 - val_loss: 1.6923 - learning_rate: 3.0000e-04
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.5316 - loss: 1.4867 - val_accuracy: 0.4748 - val_loss: 1.6547 - learning_rate: 3.0000e-04
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 128ms/step - accuracy: 0.5324 - loss: 1.4847 - val_accuracy: 0.4691 - val_loss: 1.6596 - learning_rate: 3.0000e-04
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.5351 - loss: 1.4796 - val_accuracy: 0.4619 - val_loss: 1.7089 - learning_rate: 3.0000e-04
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.5592 - loss: 1.4062 - val_accuracy: 0.5323 - val_loss: 1.4728 - learning_rate: 9.0000e-05
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.5650 - loss: 1.3793 - val_accuracy: 0.5380 - val_loss: 1.4667 - learning_rate: 9.0000e-05
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.5698 - loss: 1.3603 - val_accuracy: 0.5196 - val_loss: 1.4975 - learning_rate: 9.0000e-05
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 126ms/step - accuracy: 0.5742 - loss: 1.3448 - val_accuracy: 0.5362 - val_loss: 1.4531 - learning_rate: 9.0000e-05
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 126ms/step - accuracy: 0.5759 - loss: 1.3318 - val_accuracy: 0.5365 - val_loss: 1.4389 - learning_rate: 9.0000e-05
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 124ms/step - accuracy: 0.5794 - loss: 1.3225 - val_accuracy: 0.5362 - val_loss: 1.4428 - learning_rate: 9.0000e-05
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.5820 - loss: 1.3121 - val_accuracy: 0.5524 - val_loss: 1.4053 - learning_rate: 9.0000e-05
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 127ms/step - accuracy: 0.5876 - loss: 1.2998 - val_accuracy: 0.5382 - val_loss: 1.4546 - learning_rate: 9.0000e-05
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 125ms/step - accuracy: 0.5883 - loss: 1.2905 - val_accuracy: 0.5350 - val_loss: 1.4384 - learning_rate: 9.0000e-05
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 125ms/step - accuracy: 0.5921 - loss: 1.2858 - val_accuracy: 0.5418 - val_loss: 1.4319 - learning_rate: 9.0000e-05
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 125ms/step - accuracy: 0.5909 - loss: 1.2773 - val_accuracy: 0.5505 - val_loss: 1.4042 - learning_rate: 9.0000e-05
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 126ms/step - accuracy: 0.5986 - loss: 1.2705 - val_accuracy: 0.5446 - val_loss: 1.4191 - learning_rate: 9.0000e-05
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 124ms/step - accuracy: 0.5961 - loss: 1.2659 - val_accuracy: 0.5502 - val_loss: 1.4172 - learning_rate: 9.0000e-05
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 125ms/step - accuracy: 0.5981 - loss: 1.2609 - val_accuracy: 0.5411 - val_loss: 1.4418 - learning_rate: 9.0000e-05
# Epoch 53/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 124ms/step - accuracy: 0.6004 - loss: 1.2537 - val_accuracy: 0.5468 - val_loss: 1.4209 - learning_rate: 9.0000e-05
# Epoch 54/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 125ms/step - accuracy: 0.5988 - loss: 1.2491 - val_accuracy: 0.5492 - val_loss: 1.4171 - learning_rate: 9.0000e-05
# Epoch 55/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 125ms/step - accuracy: 0.6157 - loss: 1.2069 - val_accuracy: 0.5643 - val_loss: 1.3685 - learning_rate: 2.7000e-05
# Epoch 56/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 125ms/step - accuracy: 0.6210 - loss: 1.1920 - val_accuracy: 0.5669 - val_loss: 1.3591 - learning_rate: 2.7000e-05
# Epoch 57/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 126ms/step - accuracy: 0.6276 - loss: 1.1831 - val_accuracy: 0.5655 - val_loss: 1.3631 - learning_rate: 2.7000e-05
# Epoch 58/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 126ms/step - accuracy: 0.6257 - loss: 1.1802 - val_accuracy: 0.5642 - val_loss: 1.3615 - learning_rate: 2.7000e-05
# Epoch 59/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 124ms/step - accuracy: 0.6257 - loss: 1.1740 - val_accuracy: 0.5676 - val_loss: 1.3612 - learning_rate: 2.7000e-05
# Epoch 60/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 127ms/step - accuracy: 0.6249 - loss: 1.1735 - val_accuracy: 0.5668 - val_loss: 1.3646 - learning_rate: 2.7000e-05
# Epoch 61/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.6306 - loss: 1.1676 - val_accuracy: 0.5673 - val_loss: 1.3594 - learning_rate: 2.7000e-05
# Epoch 62/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.6336 - loss: 1.1502 - val_accuracy: 0.5746 - val_loss: 1.3420 - learning_rate: 8.1000e-06
# Epoch 63/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.6385 - loss: 1.1436 - val_accuracy: 0.5727 - val_loss: 1.3422 - learning_rate: 8.1000e-06
# Epoch 64/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 126ms/step - accuracy: 0.6383 - loss: 1.1435 - val_accuracy: 0.5724 - val_loss: 1.3454 - learning_rate: 8.1000e-06
# Epoch 65/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 126ms/step - accuracy: 0.6362 - loss: 1.1425 - val_accuracy: 0.5742 - val_loss: 1.3426 - learning_rate: 8.1000e-06
# Epoch 66/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 126ms/step - accuracy: 0.6363 - loss: 1.1447 - val_accuracy: 0.5708 - val_loss: 1.3436 - learning_rate: 8.1000e-06
# Epoch 67/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 125ms/step - accuracy: 0.6410 - loss: 1.1377 - val_accuracy: 0.5722 - val_loss: 1.3456 - learning_rate: 8.1000e-06
# Epoch 68/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.6417 - loss: 1.1322 - val_accuracy: 0.5743 - val_loss: 1.3388 - learning_rate: 2.4300e-06
# Epoch 69/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 126ms/step - accuracy: 0.6388 - loss: 1.1355 - val_accuracy: 0.5752 - val_loss: 1.3394 - learning_rate: 2.4300e-06
# Epoch 70/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 126ms/step - accuracy: 0.6390 - loss: 1.1300 - val_accuracy: 0.5747 - val_loss: 1.3387 - learning_rate: 2.4300e-06
# Epoch 71/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.6432 - loss: 1.1280 - val_accuracy: 0.5766 - val_loss: 1.3373 - learning_rate: 2.4300e-06
# Epoch 72/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 128ms/step - accuracy: 0.6421 - loss: 1.1237 - val_accuracy: 0.5762 - val_loss: 1.3385 - learning_rate: 2.4300e-06
# Epoch 73/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 129ms/step - accuracy: 0.6414 - loss: 1.1280 - val_accuracy: 0.5755 - val_loss: 1.3386 - learning_rate: 2.4300e-06
# Epoch 74/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.6414 - loss: 1.1330 - val_accuracy: 0.5757 - val_loss: 1.3375 - learning_rate: 2.4300e-06
# Epoch 75/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 129ms/step - accuracy: 0.6405 - loss: 1.1289 - val_accuracy: 0.5745 - val_loss: 1.3381 - learning_rate: 2.4300e-06
# Epoch 76/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.6434 - loss: 1.1219 - val_accuracy: 0.5760 - val_loss: 1.3391 - learning_rate: 2.4300e-06
# Epoch 77/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.6414 - loss: 1.1271 - val_accuracy: 0.5766 - val_loss: 1.3374 - learning_rate: 7.2900e-07
# Epoch 78/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.6445 - loss: 1.1231 - val_accuracy: 0.5751 - val_loss: 1.3371 - learning_rate: 7.2900e-07
# Epoch 79/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 126ms/step - accuracy: 0.6441 - loss: 1.1266 - val_accuracy: 0.5753 - val_loss: 1.3369 - learning_rate: 7.2900e-07
# Epoch 80/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 125ms/step - accuracy: 0.6428 - loss: 1.1215 - val_accuracy: 0.5751 - val_loss: 1.3367 - learning_rate: 7.2900e-07
# Epoch 81/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 126ms/step - accuracy: 0.6471 - loss: 1.1175 - val_accuracy: 0.5769 - val_loss: 1.3375 - learning_rate: 7.2900e-07
# Epoch 82/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 126ms/step - accuracy: 0.6441 - loss: 1.1236 - val_accuracy: 0.5751 - val_loss: 1.3374 - learning_rate: 7.2900e-07
# Epoch 83/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 125ms/step - accuracy: 0.6466 - loss: 1.1212 - val_accuracy: 0.5752 - val_loss: 1.3375 - learning_rate: 7.2900e-07
# Epoch 84/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.6444 - loss: 1.1218 - val_accuracy: 0.5747 - val_loss: 1.3371 - learning_rate: 7.2900e-07
# Epoch 85/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 126ms/step - accuracy: 0.6421 - loss: 1.1231 - val_accuracy: 0.5758 - val_loss: 1.3370 - learning_rate: 7.2900e-07
# Epoch 86/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 131ms/step - accuracy: 0.6450 - loss: 1.1250 - val_accuracy: 0.5756 - val_loss: 1.3371 - learning_rate: 2.1870e-07
# Epoch 87/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 51s 163ms/step - accuracy: 0.6442 - loss: 1.1176 - val_accuracy: 0.5756 - val_loss: 1.3369 - learning_rate: 2.1870e-07
# Epoch 88/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 133ms/step - accuracy: 0.6445 - loss: 1.1234 - val_accuracy: 0.5757 - val_loss: 1.3375 - learning_rate: 2.1870e-07
# Epoch 89/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 134ms/step - accuracy: 0.6446 - loss: 1.1200 - val_accuracy: 0.5757 - val_loss: 1.3368 - learning_rate: 2.1870e-07
# Epoch 90/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.6464 - loss: 1.1202 - val_accuracy: 0.5756 - val_loss: 1.3370 - learning_rate: 2.1870e-07

# %%
# TEST
score = model.evaluate(X_test_scaled, y_test_encoded, verbose=0)
print('Test loss:', score[0])
print(f'Test accuracy: {score[1]*100} %')

# GRAFY
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])


def show_the_best_predictions(model, x_test: np.array, y_test: np.array, n_of_pred: int = 10) -> None:
  mapping = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}

  predictions = model.predict(x_test)
  y_test = y_test.reshape(1,-1)
  predictions_ind = np.argmax(predictions, axis=1)
  predictions_ind = predictions_ind.reshape(1, -1)

  corect_predictions = np.where(predictions_ind == y_test)

  rows_correct = corect_predictions[1]
  predictedtions_correct = predictions[rows_correct]
  target_correct = y_test[0][rows_correct]

  max_samples = predictions[rows_correct, target_correct]
  selected_images = x_test[rows_correct]
  sorted_ind = np.argsort(max_samples)[::-1]

  images = []
  prob = []
  labels = []

  for ind in range(n_of_pred):
    index = sorted_ind[ind]
    labels.append(target_correct[index])
    prob.append(max_samples[index])
    images.append(selected_images[index])

  plt.figure(figsize=(20,10))

  images = np.concatenate(np.asarray(images),axis=1)
  plt.imshow(images)
  for ins in range(n_of_pred):
    texts = '{}: \n{:.3f} %'.format(mapping[labels[ins]], prob[ins]*100)
    plt.text((32/2) + 32*ins - len(mapping[labels[ins]]), 32*(5/4), texts)

  plt.axis('off')
  plt.show()

show_the_best_predictions(model, X_test_scaled, y_test)
# Out:
# Test loss: 1.3363763093948364
# Test accuracy: 57.30000138282776 %
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step
